# %%
import pickle

# Path to the pickle file
pickle_file_path = 'npy_dict.pkl'

# Open the pickle file in read-binary mode ('rb') and load the content
with open(pickle_file_path, 'rb') as file:
    data = pickle.load(file)

# Print or work with the loaded data
print(data)
# Out:
# {'janaghan_beautiful_1': ['/4TBHD/ISL/CodeBase/tmp/npy_tmp/12.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/13.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/14.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/15.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/16.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/17.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/18.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/19.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/20.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/21.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/22.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/23.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/24.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/25.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/26.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/27.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/28.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/29.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/30.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/31.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/32.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/33.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/34.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/35.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/36.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/37.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/38.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/39.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/40.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/41.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/42.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/43.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/44.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/45.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/46.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/47.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/48.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/49.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/50.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/51.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/52.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/53.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/54.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/55.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/56.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/57.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/58.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/59.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/60.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/61.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/62.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/63.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/64.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/65.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/66.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/67.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/68.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/69.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/70.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/71.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/72.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/73.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/74.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/75.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/76.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/77.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/78.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/79.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/80.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/81.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/82.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/83.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/84.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/85.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/86.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/87.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/88.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/89.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/90.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/91.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/92.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/93.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/94.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/95.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/96.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/97.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/98.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/99.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/100.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/101.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/102.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/103.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/104.npy', '/4TBHD/ISL/CodeBase/tmp/npy_tmp/105.npy', '/4TBHD/ISL/CodeBase ...

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import os
import re
import yaml
import pandas as pd
import csv
from model import *
import pickle


def read_config(config_file):
    with open(config_file, 'r') as file:
        config = yaml.safe_load(file)
    return config

if torch.cuda.is_available():  
    device = "cuda" 
else:  
    device = "cpu"  

print("device",device)
# Out:
# device cuda

# %%
def model_prediction(model,test_loader):
    predictions_dict = {}  # Dictionary to store inputs and their predictions
    total = 0
    # Ensure the model is in evaluation mode
    model.eval()

    # Iterate through test dataset
    for images in test_loader:
        # Extract the tensor from the list (since it's a list of inputs)
        images = images[0]  # Get the input tensor
        
        # Move images to the appropriate device (CPU/GPU)
        images = images.to(device)  # If using GPU, otherwise omit or use .to('cpu')

        # Forward pass to get logits/output
        with torch.no_grad():  # Disable gradient computation for inference
            outputs = model(images)

        # Get predictions from the maximum value
        _, predicted = torch.max(outputs.data, 1)

        # Iterate through the batch and associate each input with its prediction
        for img, pred in zip(images, predicted):
            # Store input and prediction in the dictionary
            # If you want to store the raw image tensor, do so directly:
            predictions_dict[img.cpu()] = pred.cpu().item()  # Store input tensor and predicted label

            # If you prefer to store a simpler reference (e.g., index or image number), use:
            # predictions_dict[f"input_{total}"] = pred.cpu().item()  # Use a custom key instead of the raw image

        # Update total number of processed images
        total += images.size(0)

    # Now `predictions_dict` contains all the inputs and their corresponding predictions
    # print(len(predictions_dict))
    return predictions_dict

# %%
def right_arm_folded(test_loader,input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_arm_folded.h5'))
    predictions_dict = model_prediction(model,test_loader)
    # prediction_label_dict = {
    # 0:'partially folded',
    # 1: 'folded',
    # }
    predictions_list = list(predictions_dict.values())
    # string_predictions_list = [prediction_label_dict[prediction] for prediction in predictions_list]
    return predictions_list
    
def right_forearm_orientation(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_forearm_orientation_1.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_hand_position_along_body(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_hand_position_along_body.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_elbow_orientation(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_elbow_orientation.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_palm_position(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_palm_position.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_fingers_joined(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_fingers_joined.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_finger_orientation(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/multi_people_models_1/right_fingertips_orientation.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

def right_finger_closeness_to_face(test_loader, input_dim, hidden_dim, output_dim):
    model = FeedforwardNeuralNetModel(input_dim, hidden_dim, output_dim)
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_finger_closeness_to_face.h5'))
    predictions_dict = model_prediction(model,test_loader)
    predictions_list = list(predictions_dict.values())
    return predictions_list

# %%
if __name__ == '__main__':
  config = read_config('config.yaml')
  input_dim =  config['inference']["input_dim"]
  hidden_dim =  config['inference']["hidden_dim"]

  model_list = ["10kmodels/right_arm_folded",
                "10kmodels/right_forearm_orientation",
                "10kmodels/right_hand_position_along_body",
                "10kmodels/right_elbow_orientation",
                "10kmodels/right_palm_position",
                "10kmodels/right_fingers_joined",
                "multi_people_models_1/right_fingertips_orientation",
                "10kmodels/right_finger_closeness_to_face"
                  ]
  
  pickle_file_save_dir = '/4TBHD/ISL/CodeBase'

  file_path = f'npy_dict.pkl'
  if os.path.getsize(file_path) > 0:
      with open(file_path, 'rb') as f:
          classification_dict = pickle.load(f)
  else:
      print("The file is empty.")
  
  # loop here for every image
  feature_list=[]
  for vid in classification_dict.keys():
    vector_list = []
    for img in range(len(classification_dict[vid])):
      # print("length of classification_dict",len(classification_dict))
      path = classification_dict[vid][img].replace('onlyface','keypoints').replace('jpg','npy')
      print("path",path)
      keypoint = np.load(path).reshape(1,-1)
      z_tensor = torch.tensor(keypoint, dtype=torch.float32)

      test_data = torch.utils.data.TensorDataset(z_tensor)
      test_loader = torch.utils.data.DataLoader(test_data, 1, shuffle=False)
      
      right_arm_folded_list = right_arm_folded(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_arm_folded"])
      right_forearm_orientation_list = right_forearm_orientation(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_forearm_orientation"])
      right_hand_position_along_body_list = right_hand_position_along_body(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_hand_position_along_body"])
      right_elbow_orientation_list = right_elbow_orientation(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_elbow_orientation"])
      right_palm_position_list = right_palm_position(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_palm_position"])
      right_fingers_joined_list = right_fingers_joined(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_fingers_joined"])
      right_finger_orientation_list = right_finger_orientation(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_finger_orientation"])
      right_finger_closeness_to_face_list = right_finger_closeness_to_face(test_loader,input_dim,hidden_dim,config['output_dim_mapping']["right_finger_closeness_to_face"])

      feature_vector =  right_arm_folded_list + right_forearm_orientation_list + right_hand_position_along_body_list + right_elbow_orientation_list + right_palm_position_list + right_fingers_joined_list + right_finger_orientation_list + right_finger_closeness_to_face_list
      print("feature_vector",feature_vector)
      vector_list.append(feature_vector)
    print("vector_list",len(vector_list))
    feature_list.append(vector_list)
  labels = []
  vid_name = []
  for vid in classification_dict.keys():
      labels.append(vid.split("_")[1])
      vid_name.append(vid)
  # Example DataFrame
  data = {'vid_name': vid_name,
          'feature_list': feature_list,
          'labels': labels}

  df = pd.DataFrame(data)
# Out:
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/16.npy
# /tmp/ipykernel_2570440/4293378927.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_arm_folded.h5'))
# /tmp/ipykernel_2570440/4293378927.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_forearm_orientation_1.h5'))
# /tmp/ipykernel_2570440/4293378927.py:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_hand_position_along_body.h5'))
# /tmp/ipykernel_2570440/4293378927.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_elbow_orientation.h5'))
# /tmp/ipykernel_2570440/4293378927.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_palm_position.h5'))
# /tmp/ipykernel_2570440/4293378927.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_fingers_joined.h5'))
# /tmp/ipykernel_2570440/4293378927.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/multi_people_models_1/right_fingertips_orientation.h5'))
# /tmp/ipykernel_2570440/4293378927.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/4TBHD/ISL/CodeBase/vector_models/10kmodels/right_finger_closeness_to_face.h5'))
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/17.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/18.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/19.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/20.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/21.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/22.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/23.npy
# feature_vector [2, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/24.npy
# feature_vector [2, 3, 2, 3, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/25.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/26.npy
# feature_vector [0, 3, 2, 3, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/27.npy
# feature_vector [0, 3, 2, 3, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/28.npy
# feature_vector [0, 3, 2, 3, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/29.npy
# feature_vector [1, 0, 2, 3, 0, 1, 1, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/30.npy
# feature_vector [1, 0, 2, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/31.npy
# feature_vector [1, 0, 2, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/32.npy
# feature_vector [1, 0, 0, 0, 0, 1, 4, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/33.npy
# feature_vector [1, 2, 0, 2, 0, 1, 3, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/34.npy
# feature_vector [1, 2, 0, 2, 0, 1, 3, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/35.npy
# feature_vector [1, 2, 0, 2, 0, 1, 3, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/36.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/37.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 4]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/38.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 4]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/39.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 4]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/40.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/41.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/42.npy
# feature_vector [1, 1, 0, 2, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/43.npy
# feature_vector [1, 1, 1, 2, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/44.npy
# feature_vector [1, 1, 1, 1, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/45.npy
# feature_vector [1, 1, 1, 1, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/46.npy
# feature_vector [1, 1, 1, 1, 0, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/47.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/48.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/49.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/50.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/51.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 0]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/52.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/53.npy
# feature_vector [1, 1, 1, 1, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/54.npy
# feature_vector [1, 1, 1, 2, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/55.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/56.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/57.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 7]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/58.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/59.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/60.npy
# feature_vector [1, 2, 1, 2, 0, 0, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3/61.npy
# feature_vector [1, 2, 1, 2, 4, 1, 3, 5]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/stephen_beautiful_3
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/15.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/16.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/17.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/18.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/19.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/20.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/21.npy
# feature_vector [0, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/22.npy
# feature_vector [1, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/23.npy
# feature_vector [1, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/24.npy
# feature_vector [1, 0, 2, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/25.npy
# feature_vector [1, 0, 2, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/26.npy
# feature_vector [1, 0, 2, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/27.npy
# feature_vector [1, 0, 0, 0, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/28.npy
# feature_vector [1, 0, 0, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/29.npy
# feature_vector [1, 2, 0, 2, 1, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/30.npy
# feature_vector [1, 2, 0, 2, 1, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/31.npy
# feature_vector [1, 2, 0, 2, 1, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/32.npy
# feature_vector [1, 2, 0, 2, 1, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/33.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/34.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/35.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/36.npy
# feature_vector [1, 2, 0, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/37.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/38.npy
# feature_vector [1, 2, 0, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/39.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/40.npy
# feature_vector [1, 2, 0, 2, 1, 1, 3, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/41.npy
# feature_vector [1, 2, 0, 2, 1, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/42.npy
# feature_vector [1, 2, 0, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/43.npy
# feature_vector [1, 0, 0, 2, 3, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/44.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/45.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/46.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/47.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/48.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/49.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/50.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/51.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/52.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/53.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/54.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/55.npy
# feature_vector [1, 0, 0, 2, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/56.npy
# feature_vector [1, 0, 0, 0, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/57.npy
# feature_vector [1, 0, 0, 0, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/58.npy
# feature_vector [1, 0, 2, 0, 2, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/59.npy
# feature_vector [1, 0, 2, 0, 3, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/60.npy
# feature_vector [1, 0, 2, 3, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/61.npy
# feature_vector [1, 0, 2, 3, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/62.npy
# feature_vector [1, 3, 2, 3, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/63.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/64.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/65.npy
# feature_vector [0, 3, 2, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/66.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/67.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/68.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/69.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/70.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/71.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/72.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/73.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/74.npy
# feature_vector [2, 3, 3, 2, 0, 0, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/75.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/76.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/77.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/78.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/79.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/80.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# path /4TBHD/ISL/CodeBase/Sequence_Model/seq_npy_folder/janaghan_go_3/81.npy
# feature_vector [0, 3, 2, 2, 0, 1, 0, 6]
# vector_list 67

# %%
print(len(feature_list))
# Out:
# 20

# %%
import pandas as pd

# Example DataFrame
data = {'vid_name': vid_name,
        'feature_list': feature_list,
        'labels': labels}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#               vid_name                                       feature_list  \
# 0  stephen_beautiful_3  [[2, 3, 2, 2, 0, 0, 0, 6], [2, 3, 2, 2, 0, 0, ...
# 1       stephen_cook_3  [[2, 3, 3, 2, 0, 0, 0, 6], [2, 3, 3, 2, 0, 0, ...
# 2       stephen_good_2  [[2, 3, 3, 2, 0, 0, 0, 6], [2, 3, 3, 2, 0, 0, ...
# 3   stephen_thankyou_3  [[2, 3, 2, 2, 0, 0, 0, 6], [2, 3, 2, 2, 0, 0, ...
# 4      stephen_sorry_3  [[2, 3, 3, 2, 0, 1, 0, 6], [2, 3, 3, 2, 0, 1, ...
#
#       labels
# 0  beautiful
# 1       cook
# 2       good
# 3   thankyou
# 4      sorry
